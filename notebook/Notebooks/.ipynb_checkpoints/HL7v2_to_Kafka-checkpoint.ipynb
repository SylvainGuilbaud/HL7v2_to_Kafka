# %% [markdown]
# # HL7v2 to Kafka

# %%
import pandas as pd
import intersystems_iris as iris
from sqlalchemy import create_engine,types

# %% [markdown]
# ## Create the SQL Alchemy engine

# %%
engine = create_engine('iris://SuperUser:SYS@iris:1972/IRISAPP')

# %% [markdown]
# ## Create the dbapi connection

# %%
host = "HL7v2_to_Kafka"
port = 1972
namespace = "IRISAPP"
user = "_SYSTEM"
password = "SYS"

conn = iris.connect(
                    hostname=host, 
                    port=port, 
                    namespace=namespace, 
                    username=user, 
                    password=password
                   )


cur = conn.cursor()

# %% [markdown]
# # create a cursor

# %%
print(iris)
# Out:
# <module 'intersystems_iris' from '/opt/conda/lib/python3.11/site-packages/intersystems_iris/__init__.py'>

# %%
print(engine)
# Out:
# Engine(iris://SuperUser:***@iris:1972/IRISAPP)

# %%
print(conn)
# Out:
# <intersystems_iris.IRISConnection object at 0xffff59e15690>

# %%
print(cur)
# Out:
# <intersystems_iris.dbapi._DBAPI.Cursor object at 0xffff59e14310>

# %% [markdown]
# ## Display data from HL7v2toKafka_msg.kafka using PANDA and SQLAlchemy

# %%
pd.read_sql_table('kafka', engine, schema="HL7v2toKafka_msg")
# Out:
#     ID binaryValue                      key  \
# 0    1        None  00556432^^^HospitalA^PI
# 1    2        None  00556432^^^HospitalA^PI
# 2    3        None  00556432^^^HospitalA^PI
# 3    4        None  010561081^^^TrakCare^PI
# 4    5        None    010561081^^^DxCare^PI
# 5    6        None  00556432^^^HospitalA^PI
# 6    7        None  00556432^^^HospitalA^PI
# 7    8        None  00556432^^^HospitalA^PI
# 8    9        None  010561081^^^TrakCare^PI
# 9   10        None    010561081^^^DxCare^PI
# 10  11        None  00556432^^^HospitalA^PI
# 11  12        None  00556432^^^HospitalA^PI
# 12  13        None  00556432^^^HospitalA^PI
# 13  14        None  010561081^^^TrakCare^PI
# 14  15        None    010561081^^^DxCare^PI
# 15  16        None  00556432^^^HospitalA^PI
# 16  17        None  00556432^^^HospitalA^PI
# 17  18        None  00556432^^^HospitalA^PI
# 18  19        None  00556432^^^HospitalA^PI
# 19  20        None  00556432^^^HospitalA^PI
# 20  21        None  00556432^^^HospitalA^PI
# 21  22        None  00556432^^^HospitalA^PI
# 22  23        None  00556432^^^HospitalA^PI
# 23  24        None  00556432^^^HospitalA^PI
# 24  25        None  010561081^^^TrakCare^PI
# 25  26        None  010561081^^^TrakCare^PI
# 26  27        None  010561081^^^TrakCare^PI
# 27  28        None    010561081^^^DxCare^PI
# 28  29        None    010561081^^^DxCare^PI
# 29  30        None    010561081^^^DxCare^PI
# 30  31        None  00556432^^^HospitalA^PI
# 31  32        None  00556432^^^HospitalA^PI
# 32  33        None  00556432^^^HospitalA^PI
# 33  34        None  00556432^^^HospitalA^PI
# 34  35        None  00556432^^^HospitalA^PI
# 35  36        None  00556432^^^HospitalA^PI
# 36  37        None  00556432^^^HospitalA^PI
# 37  38        None  00556432^^^HospitalA^PI
# 38  39        None  00556432^^^HospitalA^PI
# 39  40        None  010561081^^^TrakCare^PI
# 40  41        None  010561081^^^TrakCare^PI
# 41  42        None  010561081^^^TrakCare^PI
# 42  43        None    010561081^^^DxCare^PI
# 43  44        None    010561081^^^DxCare^PI
# 44  45        None    010561081^^^DxCare^PI
# 45  46        None  00556432^^^HospitalA^PI
# 46  47        None  00556432^^^HospitalA^PI
# 47  48        None  00556432^^^HospitalA^PI
# 48  49        None  00556432^^^HospitalA^PI
# 49  50        None  00556432^^^HospitalA^PI
# 50  51        None  00556432^^^HospitalA^PI
# 51  52        None  010561081^^^TrakCare^PI
# 52  53        None  00556432^^^HospitalA^PI
# 53  54        None  010561081^^^TrakCare^PI
# 54  55        None  00556432^^^HospitalA^PI
# 55  56        None  00556432^^^HospitalA^PI
# 56  57        None    010561081^^^DxCare^PI
# 57  58        None  010561081^^^TrakCare^PI
# 58  59        None    010561081^^^DxCare^PI
# 59  60        None    010561081^^^DxCare^PI
#
#                                                 topic  \
# 0   SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 1   SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 2   SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 3         APT-FROM-TRAKCARE-ENVOIE-TO-PTAH--RECEPTION
# 4       APT-FROM-DXPLANNING-ENVOIE-TO-PTAH--RECEPTION
# 5   SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 6   SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 7   SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 8         APT-FROM-TRAKCARE-ENVOIE-TO-PTAH--RECEPTION
# 9       APT-FROM-DXPLANNING-ENVOIE-TO-PTAH--RECEPTION
# 10  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 11  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 12  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 13        APT-FROM-TRAKCARE-ENVOIE-TO-PTAH--RECEPTION
# 14      APT-FROM-DXPLANNING-ENVOIE-TO-PTAH--RECEPTION
# 15  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 16  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 17  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 18  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 19  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 20  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 21  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 22  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 23  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 24        APT-FROM-TRAKCARE-ENVOIE-TO-PTAH--RECEPTION
# 25        APT-FROM-TRAKCARE-ENVOIE-TO-PTAH--RECEPTION
# 26        APT-FROM-TRAKCARE-ENVOIE-TO-PTAH--RECEPTION
# 27      APT-FROM-DXPLANNING-ENVOIE-TO-PTAH--RECEPTION
# 28      APT-FROM-DXPLANNING-ENVOIE-TO-PTAH--RECEPTION
# 29      APT-FROM-DXPLANNING-ENVOIE-TO-PTAH--RECEPTION
# 30  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 31  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 32  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 33  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 34  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 35  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 36  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 37  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 38  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 39        APT-FROM-TRAKCARE-ENVOIE-TO-PTAH--RECEPTION
# 40        APT-FROM-TRAKCARE-ENVOIE-TO-PTAH--RECEPTION
# 41        APT-FROM-TRAKCARE-ENVOIE-TO-PTAH--RECEPTION
# 42      APT-FROM-DXPLANNING-ENVOIE-TO-PTAH--RECEPTION
# 43      APT-FROM-DXPLANNING-ENVOIE-TO-PTAH--RECEPTION
# 44      APT-FROM-DXPLANNING-ENVOIE-TO-PTAH--RECEPTION
# 45  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 46  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 47  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 48  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 49  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 50  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 51        APT-FROM-TRAKCARE-ENVOIE-TO-PTAH--RECEPTION
# 52  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 53        APT-FROM-TRAKCARE-ENVOIE-TO-PTAH--RECEPTION
# 54  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 55  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 56      APT-FROM-DXPLANNING-ENVOIE-TO-PTAH--RECEPTION
# 57        APT-FROM-TRAKCARE-ENVOIE-TO-PTAH--RECEPTION
# 58      APT-FROM-DXPLANNING-ENVOIE-TO-PTAH--RECEPTION
# 59      APT-FROM-DXPLANNING-ENVOIE-TO-PTAH--RECEPTION
#
#                                                 value
# 0                202405221100 PATIENT: DOE^John^^^^^D
# 1            202405221100 PATIENT: DURO^Olivier^^^^^D
# 2   202405221100 PATIENT: DOE^Olivia^^^^^D  FIND^F...
# 3   202405221100 PATIENT: HENDRIX^Jimi^^^^^D  1010...
# 4            202405231430 PATIENT: HENDRIX^Jimi^^^^^D
# 5                202405221100 PATIENT: DOE^John^^^^^D
# 6            202405221100 PATIENT: DURO^Olivier^^^^^D
# 7   202405221100 PATIENT: DOE^Olivia^^^^^D  FIND^F...
# 8   202405221100 PATIENT: HENDRIX^Jimi^^^^^D  1010...
# 9            202405231430 PATIENT: HENDRIX^Jimi^^^^^D
# 10               202405221100 PATIENT: DOE^John^^^^^D
# 11           202405221100 PATIENT: DURO^Olivier^^^^^D
# 12  202405221100 PATIENT: DOE^Olivia^^^^^D  FIND^F...
# 13  202405221100 PATIENT: HENDRIX^Jimi^^^^^D  1010...
# 14           202405231430 PATIENT: HENDRIX^Jimi^^^^^D
# 15               202405221100 PATIENT: DOE^John^^^^^D
# 16               202405221100 PATIENT: DOE^John^^^^^D
# 17               202405221100 PATIENT: DOE^John^^^^^D
# 18           202405221100 PATIENT: DURO^Olivier^^^^^D
# 19           202405221100 PATIENT: DURO^Olivier^^^^^D
# 20           202405221100 PATIENT: DURO^Olivier^^^^^D
# 21  202405221100 PATIENT: DOE^Olivia^^^^^D  FIND^F...
# 22  202405221100 PATIENT: DOE^Olivia^^^^^D  FIND^F...
# 23  202405221100 PATIENT: DOE^Olivia^^^^^D  FIND^F...
# 24  202405221100 PATIENT: HENDRIX^Jimi^^^^^D  1010...
# 25  202405221100 PATIENT: HENDRIX^Jimi^^^^^D  1010...
# 26  202405221100 PATIENT: HENDRIX^Jimi^^^^^D  1010...
# 27           202405231430 PATIENT: HENDRIX^Jimi^^^^^D
# 28           202405231430 PATIENT: HENDRIX^Jimi^^^^^D
# 29           202405231430 PATIENT: HENDRIX^Jimi^^^^^D
# 30               202405221100 PATIENT: DOE^John^^^^^D
# 31               202405221100 PATIENT: DOE^John^^^^^D
# 32               202405221100 PATIENT: DOE^John^^^^^D
# 33           202405221100 PATIENT: DURO^Olivier^^^^^D
# 34           202405221100 PATIENT: DURO^Olivier^^^^^D
# 35           202405221100 PATIENT: DURO^Olivier^^^^^D
# 36  202405221100 PATIENT: DOE^Olivia^^^^^D  FIND^F...
# 37  202405221100 PATIENT: DOE^Olivia^^^^^D  FIND^F...
# 38  202405221100 PATIENT: DOE^Olivia^^^^^D  FIND^F...
# 39  202405221100 PATIENT: HENDRIX^Jimi^^^^^D  1010...
# 40  202405221100 PATIENT: HENDRIX^Jimi^^^^^D  1010...
# 41  202405221100 PATIENT: HENDRIX^Jimi^^^^^D  1010...
# 42           202405231430 PATIENT: HENDRIX^Jimi^^^^^D
# 43           202405231430 PATIENT: HENDRIX^Jimi^^^^^D
# 44           202405231430 PATIENT: HENDRIX^Jimi^^^^^D
# 45               202405221100 PATIENT: DOE^John^^^^^D
# 46           202405221100 PATIENT: DURO^Olivier^^^^^D
# 47  202405221100 PATIENT: DOE^Olivia^^^^^D  FIND^F...
# 48               202405221100 PATIENT: DOE^John^^^^^D
# 49           202405221100 PATIENT: DURO^Olivier^^^^^D
# 50  202405221100 PATIENT: DOE^Olivia^^^^^D  FIND^F...
# 51  202405221100 PATIENT: HENDRIX^Jimi^^^^^D  1010...
# 52               202405221100 PATIENT: DOE^John^^^^^D
# 53  202405221100 PATIENT: HENDRIX^Jimi^^^^^D  1010...
# 54           202405221100 PATIENT: DURO^Olivier^^^^^D
# 55  202405221100 PATIENT: DOE^Olivia^^^^^D  FIND^F...
# 56           202405231430 PATIENT: HENDRIX^Jimi^^^^^D
# 57  202405221100 PATIENT: HENDRIX^Jimi^^^^^D  1010...
# 58           202405231430 PATIENT: HENDRIX^Jimi^^^^^D
# 59           202405231430 PATIENT: HENDRIX^Jimi^^^^^D

# %% [markdown]
# ## Display data from HL7v2toKafka_msg.Kafka using DBAPI

# %%
sql = """
SELECT 
*
FROM HL7v2toKafka_msg.Kafka
ORDER BY ID DESC
"""
cur.execute(sql)
cur.fetchall()
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# Cell In[93], line 7
#       1 sql = """
#       2 SELECT
#       3 *
#       4 FROM HL7v2toKafka_msg.Kafka
#       5 ORDER BY ID DESC
#       6 """
# ----> 7 cur.execute(sql)
#       8 cur.fetchall()
#
# File /opt/conda/lib/python3.11/site-packages/intersystems_iris/dbapi/_DBAPI.py:220, in _BaseCursor.execute(self, operation, params)
#     219 def execute(self, operation, params=()):
# --> 220     self._is_alive()
#     222     self.statement = operation
#     223     if params and not isinstance(params, list) and not isinstance(params, tuple):
#
# File /opt/conda/lib/python3.11/site-packages/intersystems_iris/dbapi/_DBAPI.py:198, in _BaseCursor._is_alive(self)
#     196 def _is_alive(self):
#     197     if self._closed:
# --> 198         raise InterfaceError("Cursor is closed")
#     199     if self._connection == None or self._connection.isClosed():
#     200         raise InterfaceError("Connection not open")
#
# InterfaceError: Cursor is closed

# %% [markdown]
# ## Display the SQL Query from a dataframe

# %%
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#    ID binaryValue                      key  \
# 0   1        None  00556432^^^HospitalA^PI
# 1   2        None  00556432^^^HospitalA^PI
# 2   3        None  00556432^^^HospitalA^PI
# 3   4        None  010561081^^^TrakCare^PI
# 4   5        None    010561081^^^DxCare^PI
#
#                                                topic  \
# 0  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 1  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 2  SURG-FROM-SendingApp-SendingFac-TO-ReceivingAp...
# 3        APT-FROM-TRAKCARE-ENVOIE-TO-PTAH--RECEPTION
# 4      APT-FROM-DXPLANNING-ENVOIE-TO-PTAH--RECEPTION
#
#                                                value
# 0               202405221100 PATIENT: DOE^John^^^^^D
# 1           202405221100 PATIENT: DURO^Olivier^^^^^D
# 2  202405221100 PATIENT: DOE^Olivia^^^^^D  FIND^F...
# 3  202405221100 PATIENT: HENDRIX^Jimi^^^^^D  1010...
# 4           202405231430 PATIENT: HENDRIX^Jimi^^^^^D

# %%
conn.close()

# %%
cur.isClosed()
# Out:
# True

# %%
cur.close()
